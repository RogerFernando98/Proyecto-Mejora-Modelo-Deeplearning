# %%
from tensorflow import keras as ks
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# Cargamos la libreria de EarlyStop
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Definición del modelo
model = ks.Sequential()

# Capas convolucionales y de pooling con Batch Normalization
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation='softmax'))

model.summary()

# Compilación del modelo
model.compile(optimizer=ks.optimizers.Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Cargar el dataset CIFAR-10
cifar10 = ks.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

print("Etiquetas de train:", y_train)

# Convertir los datos en arrays de una dimensión (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()

print("Etiquetas de train (en vector):", y_train)

cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))

# Pintemos una muestra de las imágenes del dataset CIFAR-10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()

x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))

# Configuración del generador de datos con augmentación
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Ajustar el generador de datos al conjunto de entrenamiento
datagen.fit(x_train_scaled)

# Entrenamiento del modelo usando data augmentation
t = time.perf_counter()
history = model.fit(datagen.flow(x_train_scaled, y_train, batch_size=64),
                    epochs=300, 
                    validation_data=(x_val_scaled, y_val), 
                    callbacks=[early_stopping])
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)

# Evaluación del modelo
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))

model.evaluate(x_test_scaled, y_test, verbose=2)

# Gráficas de pérdida y precisión
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# Predicciones y visualización
predictions = model.predict(x_test)

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                  100*np.max(predictions_array),
                                  true_label),
                                  color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i+start, predictions[i+start], y_test, x_test)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\Herre\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 523,338 (2.00 MB)
#  Trainable params: 522,122 (1.99 MB)
#  Non-trainable params: 1,216 (4.75 KB)
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]
# Number of labels: 10
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)
# Epoch 1/300
# c:\Users\Herre\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.1695 - loss: 3.3187 - val_accuracy: 0.2163 - val_loss: 2.5169
# Epoch 2/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.2445 - loss: 2.6366 - val_accuracy: 0.3419 - val_loss: 2.0149
# Epoch 3/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.2750 - loss: 2.3796 - val_accuracy: 0.3678 - val_loss: 1.9627
# Epoch 4/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.3020 - loss: 2.2113 - val_accuracy: 0.3699 - val_loss: 1.9781
# Epoch 5/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.3328 - loss: 2.0962 - val_accuracy: 0.3526 - val_loss: 2.0928
# Epoch 6/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.3519 - loss: 2.0112 - val_accuracy: 0.3461 - val_loss: 2.2012
# Epoch 7/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.3719 - loss: 1.9379 - val_accuracy: 0.4010 - val_loss: 1.9507
# Epoch 8/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.3886 - loss: 1.8697 - val_accuracy: 0.4443 - val_loss: 1.7737
# Epoch 9/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.4098 - loss: 1.8075 - val_accuracy: 0.4124 - val_loss: 1.9985
# Epoch 10/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.4267 - loss: 1.7508 - val_accuracy: 0.4407 - val_loss: 1.8722
# Epoch 11/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.4354 - loss: 1.7066 - val_accuracy: 0.4165 - val_loss: 2.0267
# Epoch 12/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.4542 - loss: 1.6540 - val_accuracy: 0.4745 - val_loss: 1.7358
# Epoch 13/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.4681 - loss: 1.6199 - val_accuracy: 0.4332 - val_loss: 1.9251
# Epoch 14/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.4796 - loss: 1.5837 - val_accuracy: 0.4735 - val_loss: 1.6689
# Epoch 15/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.4923 - loss: 1.5404 - val_accuracy: 0.5086 - val_loss: 1.5510
# Epoch 16/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5009 - loss: 1.5247 - val_accuracy: 0.5191 - val_loss: 1.5144
# Epoch 17/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5087 - loss: 1.4878 - val_accuracy: 0.5480 - val_loss: 1.4077
# Epoch 18/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5199 - loss: 1.4601 - val_accuracy: 0.5796 - val_loss: 1.3066
# Epoch 19/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5266 - loss: 1.4362 - val_accuracy: 0.5426 - val_loss: 1.4251
# Epoch 20/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.5281 - loss: 1.4128 - val_accuracy: 0.5448 - val_loss: 1.4209
# Epoch 21/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5357 - loss: 1.3869 - val_accuracy: 0.5335 - val_loss: 1.4630
# Epoch 22/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5409 - loss: 1.3717 - val_accuracy: 0.5295 - val_loss: 1.4623
# Epoch 23/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5430 - loss: 1.3593 - val_accuracy: 0.5478 - val_loss: 1.4127
# Epoch 24/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.5551 - loss: 1.3300 - val_accuracy: 0.5584 - val_loss: 1.3513
# Epoch 25/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5547 - loss: 1.3203 - val_accuracy: 0.5703 - val_loss: 1.3045
# Epoch 26/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.5608 - loss: 1.3084 - val_accuracy: 0.5854 - val_loss: 1.2768
# Epoch 27/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.5663 - loss: 1.2874 - val_accuracy: 0.5525 - val_loss: 1.3839
# Epoch 28/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.5771 - loss: 1.2597 - val_accuracy: 0.5983 - val_loss: 1.2071
# Epoch 29/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.5740 - loss: 1.2640 - val_accuracy: 0.5582 - val_loss: 1.3768
# Epoch 30/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.5786 - loss: 1.2466 - val_accuracy: 0.6135 - val_loss: 1.1476
# Epoch 31/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.5835 - loss: 1.2325 - val_accuracy: 0.6081 - val_loss: 1.1623
# Epoch 32/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.5821 - loss: 1.2330 - val_accuracy: 0.6248 - val_loss: 1.1241
# Epoch 33/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.5876 - loss: 1.2169 - val_accuracy: 0.6274 - val_loss: 1.1160
# Epoch 34/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.5916 - loss: 1.2057 - val_accuracy: 0.6512 - val_loss: 1.0497
# Epoch 35/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5977 - loss: 1.1886 - val_accuracy: 0.5852 - val_loss: 1.2608
# Epoch 36/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.6015 - loss: 1.1720 - val_accuracy: 0.6123 - val_loss: 1.1581
# Epoch 37/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.6052 - loss: 1.1725 - val_accuracy: 0.6312 - val_loss: 1.0831
# Epoch 38/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.6010 - loss: 1.1655 - val_accuracy: 0.6380 - val_loss: 1.0835
# Epoch 39/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.6096 - loss: 1.1533 - val_accuracy: 0.6103 - val_loss: 1.1563
# Epoch 40/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.6125 - loss: 1.1353 - val_accuracy: 0.5787 - val_loss: 1.2755
# Epoch 41/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6139 - loss: 1.1372 - val_accuracy: 0.6467 - val_loss: 1.0535
# Epoch 42/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6186 - loss: 1.1185 - val_accuracy: 0.6112 - val_loss: 1.1747
# Epoch 43/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.6275 - loss: 1.1024 - val_accuracy: 0.6214 - val_loss: 1.1293
# Epoch 44/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6273 - loss: 1.0982 - val_accuracy: 0.6933 - val_loss: 0.9104
# Epoch 45/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.6249 - loss: 1.1000 - val_accuracy: 0.6331 - val_loss: 1.0872
# Epoch 46/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.6297 - loss: 1.0946 - val_accuracy: 0.6558 - val_loss: 1.0273
# Epoch 47/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6284 - loss: 1.0890 - val_accuracy: 0.6466 - val_loss: 1.0304
# Epoch 48/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.6336 - loss: 1.0747 - val_accuracy: 0.6518 - val_loss: 1.0276
# Epoch 49/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.6289 - loss: 1.0847 - val_accuracy: 0.6664 - val_loss: 0.9928
# Epoch 50/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6334 - loss: 1.0680 - val_accuracy: 0.6758 - val_loss: 0.9634
# Epoch 51/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6397 - loss: 1.0605 - val_accuracy: 0.6700 - val_loss: 0.9983
# Epoch 52/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6414 - loss: 1.0514 - val_accuracy: 0.6805 - val_loss: 0.9521
# Epoch 53/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6405 - loss: 1.0530 - val_accuracy: 0.7172 - val_loss: 0.8450
# Epoch 54/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6444 - loss: 1.0447 - val_accuracy: 0.6743 - val_loss: 0.9661
# Epoch 55/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6465 - loss: 1.0315 - val_accuracy: 0.6553 - val_loss: 1.0197
# Epoch 56/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6510 - loss: 1.0274 - val_accuracy: 0.6862 - val_loss: 0.9268
# Epoch 57/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6488 - loss: 1.0285 - val_accuracy: 0.6580 - val_loss: 1.0136
# Epoch 58/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6511 - loss: 1.0307 - val_accuracy: 0.7221 - val_loss: 0.8264
# Epoch 59/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6549 - loss: 1.0145 - val_accuracy: 0.6804 - val_loss: 0.9610
# Epoch 60/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6580 - loss: 1.0078 - val_accuracy: 0.7095 - val_loss: 0.8693
# Epoch 61/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6590 - loss: 1.0027 - val_accuracy: 0.6935 - val_loss: 0.9104
# Epoch 62/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6594 - loss: 0.9965 - val_accuracy: 0.6892 - val_loss: 0.9193
# Epoch 63/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6611 - loss: 0.9991 - val_accuracy: 0.7090 - val_loss: 0.8689
# Epoch 64/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6613 - loss: 0.9907 - val_accuracy: 0.6956 - val_loss: 0.9013
# Epoch 65/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6600 - loss: 0.9993 - val_accuracy: 0.7241 - val_loss: 0.8048
# Epoch 66/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6646 - loss: 0.9883 - val_accuracy: 0.6616 - val_loss: 1.0072
# Epoch 67/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6727 - loss: 0.9747 - val_accuracy: 0.6964 - val_loss: 0.9134
# Epoch 68/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6652 - loss: 0.9795 - val_accuracy: 0.7313 - val_loss: 0.7964
# Epoch 69/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6687 - loss: 0.9764 - val_accuracy: 0.7124 - val_loss: 0.8502
# Epoch 70/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6695 - loss: 0.9683 - val_accuracy: 0.7300 - val_loss: 0.7948
# Epoch 71/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6765 - loss: 0.9554 - val_accuracy: 0.7200 - val_loss: 0.8190
# Epoch 72/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6709 - loss: 0.9718 - val_accuracy: 0.7191 - val_loss: 0.8295
# Epoch 73/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6731 - loss: 0.9686 - val_accuracy: 0.7115 - val_loss: 0.8533
# Epoch 74/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6735 - loss: 0.9608 - val_accuracy: 0.7307 - val_loss: 0.7895
# Epoch 75/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6741 - loss: 0.9543 - val_accuracy: 0.7389 - val_loss: 0.7708
# Epoch 76/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6776 - loss: 0.9465 - val_accuracy: 0.6901 - val_loss: 0.9271
# Epoch 77/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6830 - loss: 0.9344 - val_accuracy: 0.7059 - val_loss: 0.8705
# Epoch 78/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6780 - loss: 0.9524 - val_accuracy: 0.6967 - val_loss: 0.9087
# Epoch 79/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6845 - loss: 0.9399 - val_accuracy: 0.6995 - val_loss: 0.8887
# Epoch 80/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6811 - loss: 0.9435 - val_accuracy: 0.7429 - val_loss: 0.7588
# Epoch 81/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6819 - loss: 0.9393 - val_accuracy: 0.7068 - val_loss: 0.8835
# Epoch 82/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6887 - loss: 0.9320 - val_accuracy: 0.7454 - val_loss: 0.7618
# Epoch 83/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6791 - loss: 0.9477 - val_accuracy: 0.6821 - val_loss: 0.9634
# Epoch 84/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6863 - loss: 0.9247 - val_accuracy: 0.7042 - val_loss: 0.8770
# Epoch 85/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6875 - loss: 0.9261 - val_accuracy: 0.7352 - val_loss: 0.7795
# Epoch 86/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6866 - loss: 0.9250 - val_accuracy: 0.7018 - val_loss: 0.8886
# Epoch 87/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6866 - loss: 0.9320 - val_accuracy: 0.7492 - val_loss: 0.7382
# Epoch 88/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6936 - loss: 0.9105 - val_accuracy: 0.7415 - val_loss: 0.7833
# Epoch 89/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6874 - loss: 0.9174 - val_accuracy: 0.7311 - val_loss: 0.7972
# Epoch 90/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6926 - loss: 0.9071 - val_accuracy: 0.7432 - val_loss: 0.7631
# Epoch 91/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6870 - loss: 0.9152 - val_accuracy: 0.7134 - val_loss: 0.8669
# Epoch 92/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6947 - loss: 0.9074 - val_accuracy: 0.7282 - val_loss: 0.7974
# Epoch 93/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6897 - loss: 0.9115 - val_accuracy: 0.7405 - val_loss: 0.7719
# Epoch 94/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6945 - loss: 0.9113 - val_accuracy: 0.6925 - val_loss: 0.9196
# Epoch 95/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7001 - loss: 0.8864 - val_accuracy: 0.7183 - val_loss: 0.8450
# Epoch 96/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6918 - loss: 0.9083 - val_accuracy: 0.7478 - val_loss: 0.7403
# Epoch 97/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6915 - loss: 0.9083 - val_accuracy: 0.7247 - val_loss: 0.8076
# Tiempo de entrenamiento: 0:37:44.682647
# > 74.690
# 313/313 - 1s - 4ms/step - accuracy: 0.7469 - loss: 0.7590
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
