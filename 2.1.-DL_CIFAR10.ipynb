# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# Cargamos la libreria de EarlyStop
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Activation, Flatten, Dense, Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

model = ks.Sequential()


model.add(Flatten())
model.add(Dense(2048, input_shape=(3072,), activation="relu")) # input_shape = 32 x 32 x 3
model.add(Dropout(0.5))
model.add(Dense(1024, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(32, activation="relu"))
model.add(Dense(10, activation="softmax"))


model.add(ks.layers.Flatten()) #El Flatten transforma la dimensionalidad de la imagen. De 2D a 1D que es lo que necesita nuestro perceptrón.
model.add(ks.layers.Dense(16, input_shape=(1024,), activation='relu')) #input_shape=(32x32,) #relu es la función de activación de la capa que hemos creado
model.add(ks.layers.Dense(10, activation='softmax')) #En la capa de salida siempre tienen que haber el mismo nº de neuronas que de imagenes a predecir, ene este caso 10
model.add(Dropout(0.5))
# Out:
# c:\Users\Herre\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 3. Optimizador, función error

# %%
from tensorflow.keras.optimizers import SGD
model.compile(optimizer=SGD(0.005),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#Funciones de pérdidas:
### categorical_crossentropy para One-Hot-Encoding
###sparse_categorical_crossentropy para decimal

# %% [markdown]
# ## 4. Preparamos los datos

# %%
#Normalización de datos numéricos
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)

# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()

print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# One Hot Encoding

# %%
#Transformación de datos categóricos a One-Hot-Encoding (etiquetas)
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %% [markdown]
# #### Añadimos Validación

# %%
from sklearn.model_selection import train_test_split

x_tr, x_val, y_tr, y_val =train_test_split(x_train, y_train, test_size=0.2, random_state=42)
print(y_tr.shape)
# Out:
# (40000, 10)

# %% [markdown]
# ### 4.1 Definimos callbacks para el Earlystoping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_tr, y_tr, validation_data=(x_val, y_val), epochs=200, batch_size=128)
# Out:
# Epoch 1/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.1032 - loss: nan - val_accuracy: 0.0984 - val_loss: 2.3127
# Epoch 2/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1093 - val_loss: 2.3040
# Epoch 3/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1023 - val_loss: 2.3093
# Epoch 4/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1028 - loss: nan - val_accuracy: 0.1115 - val_loss: 2.3034
# Epoch 5/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1014 - loss: nan - val_accuracy: 0.0928 - val_loss: 2.3027
# Epoch 6/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1000 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3040
# Epoch 7/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1023 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3035
# Epoch 8/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1009 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3032
# Epoch 9/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0995 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3031
# Epoch 10/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0988 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3029
# Epoch 11/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0984 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3029
# Epoch 12/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3028
# Epoch 13/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1009 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3028
# Epoch 14/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0960 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3028
# Epoch 15/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1033 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3028
# Epoch 16/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - accuracy: 0.0984 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3027
# Epoch 17/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.0972 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3027
# Epoch 18/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1004 - loss: nan - val_accuracy: 0.0979 - val_loss: 2.3027
# Epoch 19/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1006 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3027
# Epoch 20/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1014 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3027
# Epoch 21/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0993 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3028
# Epoch 22/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0977 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3028
# Epoch 23/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0958 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3028
# Epoch 24/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1024 - loss: nan - val_accuracy: 0.1030 - val_loss: 2.3028
# Epoch 25/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0971 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3028
# Epoch 26/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1005 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 27/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0987 - loss: nan - val_accuracy: 0.0979 - val_loss: 2.3028
# Epoch 28/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1031 - loss: nan - val_accuracy: 0.0979 - val_loss: 2.3028
# Epoch 29/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1032 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 30/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1020 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 31/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1007 - loss: nan - val_accuracy: 0.0979 - val_loss: 2.3028
# Epoch 32/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1013 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3028
# Epoch 33/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1019 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3028
# Epoch 34/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0999 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3028
# Epoch 35/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0986 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 36/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3029
# Epoch 37/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0991 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 38/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 39/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0989 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 40/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 41/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1021 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 42/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1003 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 43/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0980 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 44/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1007 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 45/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0984 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 46/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 47/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1021 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 48/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0994 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 49/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0987 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 50/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0994 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 51/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1017 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 52/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1010 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 53/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0982 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 54/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1008 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 55/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1025 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 56/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1033 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 57/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1006 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 58/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.1015 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 59/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0996 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 60/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0993 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 61/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1023 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 62/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0981 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 63/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 64/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1037 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 65/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0989 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 66/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0983 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 67/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1053 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 68/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0984 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 69/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0976 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 70/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 71/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0998 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 72/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0995 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 73/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1003 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 74/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1011 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3027
# Epoch 75/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1005 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 76/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1020 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 77/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1009 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 78/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 79/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1031 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 80/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.0992 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 81/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1002 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 82/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0998 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 83/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0975 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 84/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0988 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 85/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 86/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1003 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 87/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0987 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 88/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0995 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 89/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 90/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1012 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 91/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1037 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 92/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1030 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 93/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1003 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 94/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0984 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 95/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1029 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 96/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0982 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 97/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1019 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 98/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1041 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 99/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1040 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 100/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1033 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 101/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1008 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 102/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0978 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 103/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1044 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 104/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0977 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 105/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1021 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 106/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1005 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 107/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1043 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 108/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1010 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 109/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1009 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 110/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1009 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 111/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1028 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 112/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1016 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 113/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0995 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 114/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1019 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 115/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0992 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 116/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0980 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 117/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1024 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 118/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0969 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 119/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0999 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 120/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0984 - loss: nan - val_accuracy: 0.0996 - val_loss: 2.3027
# Epoch 121/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1048 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 122/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1014 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 123/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1029 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 124/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0980 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 125/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0977 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 126/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1020 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 127/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0991 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 128/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0992 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 129/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1040 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 130/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1037 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 131/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1012 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 132/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1021 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 133/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1007 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 134/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1011 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 135/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0999 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 136/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1028 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 137/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0950 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 138/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1045 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 139/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1007 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 140/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0984 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 141/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1042 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 142/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1013 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 143/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0987 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 144/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0986 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 145/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0983 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 146/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1004 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 147/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1045 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 148/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1007 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 149/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1020 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 150/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0979 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 151/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1003 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 152/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1024 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 153/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1040 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 154/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0989 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 155/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1033 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3028
# Epoch 156/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1007 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 157/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1028 - loss: nan - val_accuracy: 0.0979 - val_loss: 2.3028
# Epoch 158/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0979 - loss: nan - val_accuracy: 0.0979 - val_loss: 2.3028
# Epoch 159/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 840s 3s/step - accuracy: 0.1035 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 160/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.0956 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 161/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1010 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 162/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0995 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 163/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1000 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 164/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3029
# Epoch 165/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0994 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3029
# Epoch 166/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0971 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 167/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1050 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3030
# Epoch 168/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1026 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3030
# Epoch 169/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0988 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3030
# Epoch 170/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0973 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3029
# Epoch 171/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1023 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 172/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1016 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3029
# Epoch 173/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0984 - loss: nan - val_accuracy: 0.0973 - val_loss: 2.3030
# Epoch 174/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1023 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 175/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1018 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 176/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0975 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 177/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0999 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 178/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1002 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 179/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1003 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 180/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.0977 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 181/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1003 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 182/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1011 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 183/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1023 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 184/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.1044 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 185/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1042 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 186/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 187/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 188/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0966 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 189/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0995 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 190/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1013 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 191/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0973 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 192/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1015 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 193/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1042 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3029
# Epoch 194/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1011 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 195/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1000 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 196/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1015 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 197/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1048 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 198/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1001 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028
# Epoch 199/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1014 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3027
# Epoch 200/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1047 - loss: nan - val_accuracy: 0.0933 - val_loss: 2.3028

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))
print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:43:14.085224

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
model.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 2s - 5ms/step - accuracy: 0.1000 - loss: 2.3026
# [2.3026068210601807, 0.10000000149011612]

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 13
#      11 for i in range(num_images):
#      12   plt.subplot(num_rows, 2*num_cols, 2*i+1)
# ---> 13   plot_image(i+start, predictions[i+start], y_test, x_test)
#      14   plt.subplot(num_rows, 2*num_cols, 2*i+2)
#      15   plot_value_array(i+start, predictions[i+start], y_test)
#
# Cell In[19], line 10, in plot_image(i, predictions_array, true_label, img)
#       7 plt.imshow(img, cmap=plt.cm.binary)
#       9 predicted_label = np.argmax(predictions_array)
# ---> 10 if predicted_label == true_label:
#      11   color = 'blue'
#      12 else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
