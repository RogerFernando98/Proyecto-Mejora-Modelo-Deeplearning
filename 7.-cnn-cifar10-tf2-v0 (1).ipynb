# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
#Ejemplo 1
model = ks.Sequential()
#lo de los 32 son los filtros
#el Kernel zize es lo de (3,3)
#lo de strides=(1,1) es cada cuantos pixeles cambio
model.add(Conv2D(32, (3,3), strides=(1,1), padding="valid", activation="relu", input_shape=(28,28,1)))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dense(64, activation='relu'))
model.add(ks.layers.Dense(10, activation='softmax'))

# %%
#Original
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=(1,1), activation='relu',
                           padding='valid', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dense(64, activation='relu'))
model.add(ks.layers.Flatten())

model.add(ks.layers.Dense(10, activation='softmax'))

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation='relu'))
model.add(ks.layers.Dense(10, activation='softmax'))

#RESULTADO: 70%

# %%
model = ks.Sequential()

# Primera capa convolucional y de pooling
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

# Segunda capa convolucional y de pooling
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))

# Tercera capa convolucional y de pooling
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))

# Capa de flatten y densas
model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation='relu'))
model.add(ks.layers.Dense(10, activation='softmax'))
#RESULTADO: 0,7172

# %%
model = ks.Sequential()

# Capas convolucionales y de pooling
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.25))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.25))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.25))

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.25))

# Capas de flatten y densas
model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(128, activation='relu'))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation='softmax'))
#RESULTADO: 0,80810

# %%
#jugar con el nº de neuronas, el nº de capas, nº de filtros (32, 64),
#Cuando llegue a un % alto como 98% de train y 75% de test aplicamos tecnicas antioverfitting (dropout)

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 256)         295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 256)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 520906 (1.99 MB)
# Trainable params: 520906 (1.99 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

# Definición del callback EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Configuración del generador de datos con augmentación
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Ajustar el generador de datos al conjunto de entrenamiento
datagen.fit(x_train_scaled)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=100,
                 batch_size= 512, validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/100
# 79/79 [==============================] - 11s 53ms/step - loss: 2.0748 - accuracy: 0.2148 - val_loss: 2.1073 - val_accuracy: 0.2298
# Epoch 2/100
# 79/79 [==============================] - 2s 30ms/step - loss: 1.7840 - accuracy: 0.3394 - val_loss: 1.6948 - val_accuracy: 0.3802
# Epoch 3/100
# 79/79 [==============================] - 2s 28ms/step - loss: 1.5772 - accuracy: 0.4202 - val_loss: 1.4656 - val_accuracy: 0.4820
# Epoch 4/100
# 79/79 [==============================] - 2s 30ms/step - loss: 1.4616 - accuracy: 0.4672 - val_loss: 1.3199 - val_accuracy: 0.5245
# Epoch 5/100
# 79/79 [==============================] - 2s 28ms/step - loss: 1.3683 - accuracy: 0.5035 - val_loss: 1.2519 - val_accuracy: 0.5566
# Epoch 6/100
# 79/79 [==============================] - 3s 32ms/step - loss: 1.2954 - accuracy: 0.5361 - val_loss: 1.1833 - val_accuracy: 0.5726
# Epoch 7/100
# 79/79 [==============================] - 3s 32ms/step - loss: 1.2306 - accuracy: 0.5604 - val_loss: 1.0860 - val_accuracy: 0.6066
# Epoch 8/100
# 79/79 [==============================] - 2s 30ms/step - loss: 1.1793 - accuracy: 0.5798 - val_loss: 1.1073 - val_accuracy: 0.6023
# Epoch 9/100
# 79/79 [==============================] - 2s 28ms/step - loss: 1.1253 - accuracy: 0.6022 - val_loss: 1.0283 - val_accuracy: 0.6369
# Epoch 10/100
# 79/79 [==============================] - 2s 30ms/step - loss: 1.0896 - accuracy: 0.6156 - val_loss: 1.0171 - val_accuracy: 0.6378
# Epoch 11/100
# 79/79 [==============================] - 2s 28ms/step - loss: 1.0474 - accuracy: 0.6303 - val_loss: 0.9093 - val_accuracy: 0.6824
# Epoch 12/100
# 79/79 [==============================] - 3s 32ms/step - loss: 1.0089 - accuracy: 0.6488 - val_loss: 0.8653 - val_accuracy: 0.6974
# Epoch 13/100
# 79/79 [==============================] - 2s 29ms/step - loss: 0.9730 - accuracy: 0.6622 - val_loss: 0.8970 - val_accuracy: 0.6833
# Epoch 14/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.9491 - accuracy: 0.6692 - val_loss: 0.8337 - val_accuracy: 0.7087
# Epoch 15/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.9111 - accuracy: 0.6818 - val_loss: 0.8167 - val_accuracy: 0.7118
# Epoch 16/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.8917 - accuracy: 0.6923 - val_loss: 0.7729 - val_accuracy: 0.7321
# Epoch 17/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.8594 - accuracy: 0.7010 - val_loss: 0.7678 - val_accuracy: 0.7341
# Epoch 18/100
# 79/79 [==============================] - 3s 33ms/step - loss: 0.8428 - accuracy: 0.7089 - val_loss: 0.7575 - val_accuracy: 0.7351
# Epoch 19/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.8161 - accuracy: 0.7189 - val_loss: 0.7180 - val_accuracy: 0.7538
# Epoch 20/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.7944 - accuracy: 0.7231 - val_loss: 0.7212 - val_accuracy: 0.7473
# Epoch 21/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.7820 - accuracy: 0.7280 - val_loss: 0.7607 - val_accuracy: 0.7392
# Epoch 22/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.7648 - accuracy: 0.7327 - val_loss: 0.6919 - val_accuracy: 0.7629
# Epoch 23/100
# 79/79 [==============================] - 3s 32ms/step - loss: 0.7422 - accuracy: 0.7422 - val_loss: 0.6733 - val_accuracy: 0.7629
# Epoch 24/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.7308 - accuracy: 0.7462 - val_loss: 0.6922 - val_accuracy: 0.7588
# Epoch 25/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.7163 - accuracy: 0.7538 - val_loss: 0.6730 - val_accuracy: 0.7674
# Epoch 26/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.7124 - accuracy: 0.7537 - val_loss: 0.6666 - val_accuracy: 0.7682
# Epoch 27/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.6915 - accuracy: 0.7581 - val_loss: 0.6871 - val_accuracy: 0.7634
# Epoch 28/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6734 - accuracy: 0.7667 - val_loss: 0.6656 - val_accuracy: 0.7717
# Epoch 29/100
# 79/79 [==============================] - 3s 33ms/step - loss: 0.6629 - accuracy: 0.7702 - val_loss: 0.6230 - val_accuracy: 0.7831
# Epoch 30/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.6506 - accuracy: 0.7749 - val_loss: 0.6225 - val_accuracy: 0.7842
# Epoch 31/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.6437 - accuracy: 0.7776 - val_loss: 0.6451 - val_accuracy: 0.7773
# Epoch 32/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6326 - accuracy: 0.7811 - val_loss: 0.6367 - val_accuracy: 0.7815
# Epoch 33/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.6246 - accuracy: 0.7830 - val_loss: 0.6382 - val_accuracy: 0.7797
# Epoch 34/100
# 79/79 [==============================] - 3s 37ms/step - loss: 0.6158 - accuracy: 0.7851 - val_loss: 0.6049 - val_accuracy: 0.7912
# Epoch 35/100
# 79/79 [==============================] - 3s 34ms/step - loss: 0.6054 - accuracy: 0.7878 - val_loss: 0.5956 - val_accuracy: 0.7915
# Epoch 36/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.5868 - accuracy: 0.7952 - val_loss: 0.6170 - val_accuracy: 0.7876
# Epoch 37/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.5824 - accuracy: 0.7957 - val_loss: 0.6052 - val_accuracy: 0.7888
# Epoch 38/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.5790 - accuracy: 0.7990 - val_loss: 0.6247 - val_accuracy: 0.7834
# Epoch 39/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5625 - accuracy: 0.8040 - val_loss: 0.6172 - val_accuracy: 0.7893
# Epoch 40/100
# 79/79 [==============================] - 3s 32ms/step - loss: 0.5674 - accuracy: 0.8044 - val_loss: 0.6143 - val_accuracy: 0.7888
# Epoch 41/100
# 79/79 [==============================] - 2s 32ms/step - loss: 0.5533 - accuracy: 0.8074 - val_loss: 0.5898 - val_accuracy: 0.7966
# Epoch 42/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.5391 - accuracy: 0.8119 - val_loss: 0.6550 - val_accuracy: 0.7811
# Epoch 43/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5348 - accuracy: 0.8146 - val_loss: 0.6367 - val_accuracy: 0.7829
# Epoch 44/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.5300 - accuracy: 0.8155 - val_loss: 0.5843 - val_accuracy: 0.7988
# Epoch 45/100
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5286 - accuracy: 0.8148 - val_loss: 0.5897 - val_accuracy: 0.7989
# Epoch 46/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.5245 - accuracy: 0.8174 - val_loss: 0.6674 - val_accuracy: 0.7759
# Epoch 47/100
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5159 - accuracy: 0.8205 - val_loss: 0.6401 - val_accuracy: 0.7855
# Epoch 48/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.5087 - accuracy: 0.8220 - val_loss: 0.6122 - val_accuracy: 0.7916
# Epoch 49/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.5014 - accuracy: 0.8256 - val_loss: 0.5736 - val_accuracy: 0.8087
# Epoch 50/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4944 - accuracy: 0.8256 - val_loss: 0.5977 - val_accuracy: 0.7966
# Epoch 51/100
# 79/79 [==============================] - 2s 32ms/step - loss: 0.4913 - accuracy: 0.8287 - val_loss: 0.6164 - val_accuracy: 0.7941
# Epoch 52/100
# 79/79 [==============================] - 3s 33ms/step - loss: 0.4883 - accuracy: 0.8303 - val_loss: 0.6015 - val_accuracy: 0.7983
# Epoch 53/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4802 - accuracy: 0.8338 - val_loss: 0.6266 - val_accuracy: 0.7886
# Epoch 54/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4810 - accuracy: 0.8319 - val_loss: 0.6025 - val_accuracy: 0.7946
# Epoch 55/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4784 - accuracy: 0.8327 - val_loss: 0.5982 - val_accuracy: 0.7973
# Epoch 56/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4635 - accuracy: 0.8385 - val_loss: 0.6020 - val_accuracy: 0.7995
# Epoch 57/100
# 79/79 [==============================] - 3s 32ms/step - loss: 0.4647 - accuracy: 0.8388 - val_loss: 0.6335 - val_accuracy: 0.7903
# Epoch 58/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.4575 - accuracy: 0.8397 - val_loss: 0.5868 - val_accuracy: 0.8079
# Epoch 59/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4536 - accuracy: 0.8395 - val_loss: 0.6130 - val_accuracy: 0.7959
# Epoch 60/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4566 - accuracy: 0.8407 - val_loss: 0.6157 - val_accuracy: 0.7961
# Epoch 61/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4516 - accuracy: 0.8413 - val_loss: 0.5860 - val_accuracy: 0.8091
# Epoch 62/100
# 79/79 [==============================] - 2s 29ms/step - loss: 0.4474 - accuracy: 0.8454 - val_loss: 0.6030 - val_accuracy: 0.8003
# Epoch 63/100
# 79/79 [==============================] - 3s 33ms/step - loss: 0.4383 - accuracy: 0.8448 - val_loss: 0.5882 - val_accuracy: 0.8048
# Epoch 64/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.4259 - accuracy: 0.8511 - val_loss: 0.6037 - val_accuracy: 0.8047
# Epoch 65/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4385 - accuracy: 0.8451 - val_loss: 0.5782 - val_accuracy: 0.8085
# Epoch 66/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4325 - accuracy: 0.8476 - val_loss: 0.5962 - val_accuracy: 0.8053
# Epoch 67/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4170 - accuracy: 0.8544 - val_loss: 0.5827 - val_accuracy: 0.8064
# Epoch 68/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4202 - accuracy: 0.8537 - val_loss: 0.6003 - val_accuracy: 0.8040
# Epoch 69/100
# 79/79 [==============================] - 3s 33ms/step - loss: 0.4213 - accuracy: 0.8529 - val_loss: 0.6017 - val_accuracy: 0.8039
# Epoch 70/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4076 - accuracy: 0.8577 - val_loss: 0.5987 - val_accuracy: 0.8070
# Epoch 71/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4128 - accuracy: 0.8562 - val_loss: 0.5919 - val_accuracy: 0.8043
# Epoch 72/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3994 - accuracy: 0.8569 - val_loss: 0.5830 - val_accuracy: 0.8094
# Epoch 73/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4037 - accuracy: 0.8583 - val_loss: 0.5938 - val_accuracy: 0.8074
# Epoch 74/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.4024 - accuracy: 0.8608 - val_loss: 0.6124 - val_accuracy: 0.8044
# Epoch 75/100
# 79/79 [==============================] - 3s 32ms/step - loss: 0.4013 - accuracy: 0.8595 - val_loss: 0.5875 - val_accuracy: 0.8110
# Epoch 76/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.3962 - accuracy: 0.8613 - val_loss: 0.5905 - val_accuracy: 0.8092
# Epoch 77/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3999 - accuracy: 0.8620 - val_loss: 0.5936 - val_accuracy: 0.8073
# Epoch 78/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3791 - accuracy: 0.8679 - val_loss: 0.5918 - val_accuracy: 0.8106
# Epoch 79/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3936 - accuracy: 0.8627 - val_loss: 0.6118 - val_accuracy: 0.8028
# Epoch 80/100
# 79/79 [==============================] - 2s 32ms/step - loss: 0.3890 - accuracy: 0.8643 - val_loss: 0.6174 - val_accuracy: 0.8033
# Epoch 81/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3846 - accuracy: 0.8651 - val_loss: 0.6016 - val_accuracy: 0.8079
# Epoch 82/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3850 - accuracy: 0.8658 - val_loss: 0.5874 - val_accuracy: 0.8116
# Epoch 83/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3786 - accuracy: 0.8662 - val_loss: 0.6220 - val_accuracy: 0.7999
# Epoch 84/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3808 - accuracy: 0.8676 - val_loss: 0.6037 - val_accuracy: 0.8077
# Epoch 85/100
# 79/79 [==============================] - 2s 32ms/step - loss: 0.3821 - accuracy: 0.8674 - val_loss: 0.6214 - val_accuracy: 0.8019
# Epoch 86/100
# 79/79 [==============================] - 3s 33ms/step - loss: 0.3761 - accuracy: 0.8699 - val_loss: 0.6261 - val_accuracy: 0.8011
# Epoch 87/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3775 - accuracy: 0.8673 - val_loss: 0.6183 - val_accuracy: 0.8013
# Epoch 88/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3715 - accuracy: 0.8707 - val_loss: 0.5936 - val_accuracy: 0.8071
# Epoch 89/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3672 - accuracy: 0.8725 - val_loss: 0.6069 - val_accuracy: 0.8091
# Epoch 90/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3683 - accuracy: 0.8714 - val_loss: 0.6261 - val_accuracy: 0.8027
# Epoch 91/100
# 79/79 [==============================] - 3s 33ms/step - loss: 0.3573 - accuracy: 0.8757 - val_loss: 0.6281 - val_accuracy: 0.8018
# Epoch 92/100
# 79/79 [==============================] - 3s 32ms/step - loss: 0.3635 - accuracy: 0.8741 - val_loss: 0.6071 - val_accuracy: 0.8095
# Epoch 93/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3610 - accuracy: 0.8746 - val_loss: 0.6397 - val_accuracy: 0.8004
# Epoch 94/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3609 - accuracy: 0.8716 - val_loss: 0.6250 - val_accuracy: 0.8049
# Epoch 95/100
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3615 - accuracy: 0.8744 - val_loss: 0.6055 - val_accuracy: 0.8112
# Epoch 96/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.3605 - accuracy: 0.8745 - val_loss: 0.6353 - val_accuracy: 0.8027
# Epoch 97/100
# 79/79 [==============================] - 3s 33ms/step - loss: 0.3595 - accuracy: 0.8728 - val_loss: 0.6043 - val_accuracy: 0.8088
# Epoch 98/100
# 79/79 [==============================] - 2s 31ms/step - loss: 0.3508 - accuracy: 0.8773 - val_loss: 0.6123 - val_accuracy: 0.8083
# Epoch 99/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3472 - accuracy: 0.8779 - val_loss: 0.6443 - val_accuracy: 0.7994
# Epoch 100/100
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3527 - accuracy: 0.8777 - val_loss: 0.6195 - val_accuracy: 0.8092

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:04:24.788915

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.530

# %%
model.evaluate(x_test_scaled,  y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.6354 - accuracy: 0.8053 - 974ms/epoch - 3ms/step
# [0.6353790163993835, 0.8052999973297119]

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
